# %%
import re 
import fasttext

# %%
model = fasttext.train_unsupervised('indonesian_text/news_content.txt')
# Out:
# Read 23M words
# Number of words:  86835
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   74111 lr:  0.000000 avg.loss:  1.130911 ETA:   0h 0m 0s  3.3% words/sec/thread:   71032 lr:  0.048371 avg.loss:  1.810708 ETA:   0h 3m50s 24.5% words/sec/thread:   72519 lr:  0.037737 avg.loss:  1.752033 ETA:   0h 2m56s96.8% words/sec/thread:   74112 lr:  0.001612 avg.loss:  1.158417 ETA:   0h 0m 7s

# %%
model.save_model('data/news_content.bin')

# %%
models = fasttext.load_model('data/news_content.bin')
models.words
# Out:
# ['yang',
#  'di',
#  'dan',
#  'dengan',
#  'untuk',
#  'ini',
#  'dalam',
#  'dari',
#  'itu',
#  'pada',
#  'ke',
#  'juga',
#  'tidak',
#  'akan',
#  'jakarta',
#  'kata',
#  'ada',
#  '</s>',
#  'saat',
#  'oleh',
#  'tersebut',
#  'sebagai',
#  'menjadi',
#  'sudah',
#  'atau',
#  'indonesia',
#  'bisa',
#  'karena',
#  'bahwa',
#  'kita',
#  'telah',
#  'mengatakan',
#  'saya',
#  'tahun',
#  'kepada',
#  'sini',
#  'lebih',
#  'dia',
#  'berita',
#  'kami',
#  'sedikit',
#  'baca',
#  'iklan',
#  'klik',
#  'satu',
#  'adalah',
#  'ia',
#  'presiden',
#  'negara',
#  'hingga',
#  'orang',
#  'ujar',
#  'mereka',
#  'prabowo',
#  'para',
#  'masyarakat',
#  'hari',
#  'korban',
#  'pemerintah',
#  'masih',
#  'secara',
#  'melakukan',
#  'dapat',
#  'rp',
#  'kota',
#  'menteri',
#  'terhadap',
#  'harus',
#  'setelah',
#  'hanya',
#  'anak',
#  'seperti',
#  'serta',
#  'bagi',
#  'warga',
#  'dilakukan',
#  'dua',
#  'hal',
#  'ketua',
#  'kasus',
#  'kepala',
#  'atas',
# ...
